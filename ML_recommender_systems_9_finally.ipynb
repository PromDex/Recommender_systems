# %% [markdown]
# # Рекомендательные системы. Финальный проект

# %% [markdown]
# ### Загрузите задание на проверку до 6 июля, 20:00 +03:00 UTC

# %%
import pandas as pd
import numpy as np

# Для работы с матрицами
from scipy.sparse import csr_matrix

# Матричная факторизация
from implicit import als

from gensim.models import Word2Vec

# Модель второго уровня
from catboost import CatBoostClassifier

import os, sys
sys.path.insert(1, os.getcwd() + '/src/')


from src.metrics import precision_at_k, recall_at_k
from src.utils import prefilter_items
from src.recommenders import MainRecommender

import warnings
warnings.filterwarnings('ignore')

# %%
print(sys.version)
# Out:
# 3.10.9 | packaged by Anaconda, Inc. | (main, Mar  1 2023, 18:18:15) [MSC v.1916 64 bit (AMD64)]

# %%
print("Pandas version:", pd.__version__)
print("NumPy version:", np.__version__)
print("Scipy version:", scipy.__version__)
print("Sklearn version:", sklearn.__version__)
# Out:
# Pandas version: 2.0.2
# NumPy version: 1.25.0
# Scipy version: 1.10.1
# Sklearn version: 1.2.2

# %%
data = pd.read_csv('C:\\Users\\SAMOL\\000 Рекомендательные системы\\retail_train.csv')
item_features = pd.read_csv('C:\\Users\\SAMOL\\000 Рекомендательные системы\\product.csv')
user_features = pd.read_csv('C:\\Users\\SAMOL\\000 Рекомендательные системы\\hh_demographic.csv')

# %%
N_PREDICT = 100

# %%
# Добавим необходимые функции

def print_stats_data(df_data, name_df):
    print(name_df)
    print(f"Shape: {df_data.shape} Users: {df_data[USER_COL].nunique()} Items: {df_data[ITEM_COL].nunique()}")
    
def make_recommendations(df_result, recommend_model, N_PREDICT=N_PREDICT, USER_COL='user_id'):
    return df_result[USER_COL].apply(lambda x: recommend_model(x, N=N_PREDICT))

def calc_recall(df_data, top_k, ACTUAL_COL='actual'):
    for col_name in df_data.columns[2:]:
        yield col_name, df_data.apply(lambda row: recall_at_k(row[col_name], row[ACTUAL_COL], k=top_k), axis=1).mean()
        
def calc_precision(df_data, top_k, ACTUAL_COL='actual'):
    for col_name in df_data.columns[2:]:
        yield col_name, df_data.apply(lambda row: precision_at_k(row[col_name], row[ACTUAL_COL], k=top_k), axis=1).mean()
        
def rerank(user_id, df, USER_COL='user_id', proba_col_name='proba_item_purchase', N=5):
    return df[df[USER_COL]==user_id].sort_values(proba_col_name, ascending=False).head(N).item_id.tolist()

def get_scores(df_result, recommend_model, N_PREDICT=N_PREDICT, USER_COL='user_id'):
    return df_result[USER_COL].apply(lambda x: recommend_model(x, N=N_PREDICT))

# %%
#3. Подготовка данных
#Проведем переименования определенных признаков и приведем названия к единообразному формату.

ITEM_COL = 'item_id'
USER_COL = 'user_id'

# column processing
item_features.columns = [col.lower() for col in item_features.columns]
user_features.columns = [col.lower() for col in user_features.columns]

item_features.rename(columns={'product_id': ITEM_COL}, inplace=True)
user_features.rename(columns={'household_key': USER_COL }, inplace=True)

# %%
#Разделим выборку на обучающий, валидационный и тестовый датасеты.

VAL_MATCHER_WEEKS = 5
VAL_RANKER_WEEKS = 3

# берем данные для тренировки matching модели
data_train_matcher = data[data['week_no'] < data['week_no'].max() - (VAL_MATCHER_WEEKS + VAL_RANKER_WEEKS)]

# берем данные для валидации matching модели
data_val_matcher = data[(data['week_no'] >= data['week_no'].max() - (VAL_MATCHER_WEEKS + VAL_RANKER_WEEKS)) &
                      (data['week_no'] < data['week_no'].max() - (VAL_RANKER_WEEKS))]

# берем данные для тренировки ranking модели
data_train_ranker = data_val_matcher.copy()  # Для наглядности. Далее мы добавим изменения, и они будут отличаться

# берем данные для теста ranking, matching модели
data_val_ranker = data[data['week_no'] >= data['week_no'].max() - VAL_RANKER_WEEKS]

# %%
print_stats_data(data_train_matcher,'train_matcher')
print_stats_data(data_val_matcher,'val_matcher')
print_stats_data(data_train_ranker,'train_ranker')
print_stats_data(data_val_ranker,'val_ranker')
# Out:
# train_matcher
# Shape: (2136728, 12) Users: 2498 Items: 84180
# val_matcher
# Shape: (141762, 12) Users: 2097 Items: 25770
# train_ranker
# Shape: (141762, 12) Users: 2097 Items: 25770
# val_ranker
# Shape: (118314, 12) Users: 2042 Items: 24329

# %%
#Проведем префильтрацию данных.
n_items_before = data_train_matcher['item_id'].nunique()

data_train_matcher = prefilter_items(data_train_matcher, item_features=item_features, take_n_popular=10000)

n_items_after = data_train_matcher['item_id'].nunique()
print('Decreased # items from {} to {}'.format(n_items_before, n_items_after))
# Out:
# Decreased # items from 84180 to 10001

# %%
#Оставим только пользователей, которые встречаются в тренировочном датасете, чтобы избежать проблемы холодного старта.

# ищем общих пользователей
common_users = data_train_matcher.user_id.values

data_val_matcher = data_val_matcher[data_val_matcher.user_id.isin(common_users)]
data_train_ranker = data_train_ranker[data_train_ranker.user_id.isin(common_users)]
data_val_ranker = data_val_ranker[data_val_ranker.user_id.isin(common_users)]

print_stats_data(data_train_matcher,'train_matcher')
print_stats_data(data_val_matcher,'val_matcher')
print_stats_data(data_train_ranker,'train_ranker')
print_stats_data(data_val_ranker,'val_ranker')
# Out:
# train_matcher
# Shape: (872777, 13) Users: 2496 Items: 10001
# val_matcher
# Shape: (141737, 12) Users: 2095 Items: 25768
# train_ranker
# Shape: (141737, 12) Users: 2095 Items: 25768
# val_ranker
# Shape: (118282, 12) Users: 2040 Items: 24325

# %%
#4. Построение модели первого уровня
#Создадим экземляр класса MainRecommender.
recommender = MainRecommender(data_train_matcher)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/10001 [00:00<?, ?it/s]
#   0%|          | 0/10001 [00:00<?, ?it/s]
#   0%|          | 0/10001 [00:00<?, ?it/s]
#   0%|          | 0/10001 [00:00<?, ?it/s]

# %%
ACTUAL_COL = 'actual'
result_eval_matcher = data_val_matcher.groupby(USER_COL)[ITEM_COL].unique().reset_index()
result_eval_matcher.columns=[USER_COL, ACTUAL_COL]
result_eval_matcher.head(2)
# Out:
#    user_id                                             actual
# 0        1  [1005186, 907466, 909497, 940947, 963542, 1067...
# 1        2  [15830248, 838136, 839656, 861272, 866211, 870...

# %%
result_eval_matcher['own_rec'] = make_recommendations(result_eval_matcher, 
                                                      recommender.get_own_recommendations, 
                                                      N_PREDICT=N_PREDICT)

result_eval_matcher['als_rec'] = make_recommendations(result_eval_matcher, 
                                                      recommender.get_als_recommendations, 
                                                      N_PREDICT=N_PREDICT)

result_eval_matcher['bm25_rec'] = make_recommendations(result_eval_matcher, 
                                                      recommender.get_bm25_recommendations, 
                                                      N_PREDICT=N_PREDICT)

result_eval_matcher['tfidf_rec'] = make_recommendations(result_eval_matcher, 
                                                      recommender.get_tfidf_recommendations, 
                                                      N_PREDICT=N_PREDICT)

result_eval_matcher['cosine_rec'] = make_recommendations(result_eval_matcher, 
                                                      recommender.get_cosine_recommendations, 
                                                      N_PREDICT=N_PREDICT)
result_eval_matcher.head(2)
# Out:
#    user_id                                             actual  \
# 0        1  [1005186, 907466, 909497, 940947, 963542, 1067...
# 1        2  [15830248, 838136, 839656, 861272, 866211, 870...
#
#                                              own_rec  \
# 0  [865334, 1029743, 1106523, 5569230, 916122, 84...
# 1  [865334, 1029743, 1106523, 5569230, 916122, 84...
#
#                                              als_rec  \
# 0  [872137, 1029743, 5569374, 871570, 859191, 878...
# 1  [930118, 12302069, 5569845, 5569230, 1068719, ...
#
#                                             bm25_rec  \
# 0  [865334, 1017711, 12384779, 1000328, 1056413, ...
# 1  [865334, 1017711, 12384779, 1000328, 1056413, ...
#
#                                            tfidf_rec  \
# 0  [865334, 1017711, 983646, 847292, 1001369, 998...
# 1  [865334, 1017711, 983646, 847292, 1001369, 998...
#
#                                           cosine_rec
# 0  [865334, 1017711, 1029743, 1106523, 5569230, 9...
# 1  [865334, 1017711, 1029743, 1106523, 5569230, 9...

# %%
TOPK_RECALL = 100
sorted(calc_recall(result_eval_matcher, TOPK_RECALL), key=lambda x: x[1],reverse=True)
# Out:
# [('als_rec', 0.12413498441309054),
#  ('own_rec', 0.06061789561946516),
#  ('cosine_rec', 0.06039421560342006),
#  ('bm25_rec', 0.05545359377601677),
#  ('tfidf_rec', 0.055362395918756566)]

# %% [markdown]
# ### Генерация признаков для модели второго уровня
# Cформируем датасет для построения модели ранжирования, сгенерируем новые признаки и построим модель, которая будет работать с отобранными товарами для построения окончательных рекомендаций.

# %%
# Пользователи из трейна для ранжирования
# Создали DataFrame с уникальными идентификаторами пользователей.
df_match_candidates = pd.DataFrame(data_train_ranker[USER_COL].unique(), columns=[USER_COL])
# Сгенерировали рекомендации, используя функцию рекомендации_модели.
df_match_candidates['candidates'] = df_match_candidates[USER_COL].apply(lambda x: recommender.get_own_recommendations(x, N=N_PREDICT))
# Вычислим баллы для каждого пользователя  в кадре данных df_match_candidates на основе собственного механизма оценки рекомендаций
df_match_candidates['candidates_scores'] = get_scores(df_match_candidates,recommender.get_own_scores,N_PREDICT=N_PREDICT)
df_items = df_match_candidates.apply(lambda x: pd.Series(x['candidates']), axis=1).stack().\
            reset_index(level=1, drop=True)
df_scores = df_match_candidates.apply(lambda x: pd.Series(x['candidates_scores']), axis=1).stack().\
            reset_index(level=1, drop=True)
# предоставляем описательную метку для столбца,упрощая обращение к DataFrame и работу с ним в последующем коде.
df_items.name = 'item_id'
# удалим столбцы «candidates» и «candidates_scores» из df_match_candidates и заменим их столбцом «item_id» из df_items.
# заменим исходные столбцы новым столбцом, содержащим идентификаторы элементов.
df_match_candidates = df_match_candidates.drop(['candidates', 'candidates_scores'], axis=1).join(df_items)
# добавим столбец item_score в df_match_candidates и заполним его оценками, полученными из серии df_scores.
df_match_candidates['item_score'] = df_scores
df_match_candidates.head()
# Out:
#    user_id  item_id     item_score
# 0     1827   865334   1.116820e+04
# 0     1827  1029743   1.116820e+04
# 0     1827  1106523 -1.797693e+308
# 0     1827  5569230 -1.797693e+308
# 0     1827   916122 -1.797693e+308

# %%
df_ranker_train = data_train_ranker[[USER_COL, ITEM_COL]].copy()
df_ranker_train['target'] = 1  # тут только покупки 

df_ranker_train = df_match_candidates.merge(df_ranker_train, on=[USER_COL, ITEM_COL], how='left')

# чистим дубликаты
df_ranker_train = df_ranker_train.drop_duplicates(subset=[USER_COL, ITEM_COL])

df_ranker_train['target'].fillna(0, inplace= True)

df_ranker_train.head()
# Out:
#    user_id  item_id     item_score  target
# 0     1827   865334   1.116820e+04     0.0
# 1     1827  1029743   1.116820e+04     1.0
# 3     1827  1106523 -1.797693e+308     0.0
# 4     1827  5569230 -1.797693e+308     0.0
# 5     1827   916122 -1.797693e+308     0.0

# %%
df_ranker_train.target.value_counts()
# Out:
# target
# 0.0    202695
# 1.0      6805
# Name: count, dtype: int64

# %%
df_ranker_train = df_ranker_train.merge(item_features, on='item_id', how='left')
df_ranker_train = df_ranker_train.merge(user_features, on='user_id', how='left')

df_ranker_train.head(2)
# Out:
#    user_id  item_id    item_score  target  manufacturer department     brand  \
# 0     1827   865334  11168.201881     0.0           870    DRUG GM  National
# 1     1827  1029743  11168.201881     1.0            69    GROCERY   Private
#
#         commodity_desc     sub_commodity_desc curr_size_of_product age_desc  \
# 0            LAXATIVES              LAXATIVES                           NaN
# 1  FLUID MILK PRODUCTS  FLUID MILK WHITE ONLY                 1 GA      NaN
#
#   marital_status_code income_desc homeowner_desc hh_comp_desc  \
# 0                 NaN         NaN            NaN          NaN
# 1                 NaN         NaN            NaN          NaN
#
#   household_size_desc kid_category_desc
# 0                 NaN               NaN
# 1                 NaN               NaN

# %% [markdown]
# ### Сгенерируем новые типовые признаки и добавим их к датасету для обучения.

# %%
# Добавим параметр категории к исходному обучающему датасету для удобства создания новых фичей
data_department = data_train_ranker.merge(item_features[['item_id', 'department']], on='item_id', how='inner')
data_department.head(2)
# Out:
#    user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 0     1827  40702967646  601   891141         2         2.73     33923
# 1      496  40739402373  603   891141         1         1.83       445
#
#    retail_disc  trans_time  week_no  coupon_disc  coupon_match_disc department
# 0          0.0           7       87          0.0                0.0    PRODUCE
# 1          0.0        2226       87          0.0                0.0    PRODUCE

# %%
# Средная цена купленных товаров пользователем
users_sales = data_train_ranker.groupby(USER_COL)[['sales_value', 'quantity']].sum().reset_index()
users_sales['avg_price'] = users_sales['sales_value'] / users_sales['quantity']
df_ranker_train = df_ranker_train.merge(users_sales[['user_id', 'avg_price']], on='user_id', how='left')
df_ranker_train.head(2)
# Out:
#    user_id  item_id    item_score  target  manufacturer department     brand  \
# 0     1827   865334  11168.201881     0.0           870    DRUG GM  National
# 1     1827  1029743  11168.201881     1.0            69    GROCERY   Private
#
#         commodity_desc     sub_commodity_desc curr_size_of_product age_desc  \
# 0            LAXATIVES              LAXATIVES                           NaN
# 1  FLUID MILK PRODUCTS  FLUID MILK WHITE ONLY                 1 GA      NaN
#
#   marital_status_code income_desc homeowner_desc hh_comp_desc  \
# 0                 NaN         NaN            NaN          NaN
# 1                 NaN         NaN            NaN          NaN
#
#   household_size_desc kid_category_desc  avg_price
# 0                 NaN               NaN   2.208947
# 1                 NaN               NaN   2.208947

# %%
# Количество покупок в каждой категории и средная сумма покупки в каждой категории для пользователя
users_sales_department = data_department.groupby([USER_COL, 'department'])\
                        [['sales_value', 'quantity']].sum().reset_index()
users_sales_department.rename(columns={'quantity': 'n_sold_category'}, inplace=True)
users_sales_department['avg_transaction_category'] = users_sales_department['sales_value']\
                                                    /users_sales_department['n_sold_category']
users_sales_department.drop(columns=['sales_value'], inplace=True)

df_ranker_train = df_ranker_train.merge(
    users_sales_department, on=[USER_COL, 'department'], how='left')
df_ranker_train['Missing n_sold_category'] = 0
df_ranker_train.loc[df_ranker_train['n_sold_category'].isna(), 'Missing n_sold_category'] = 1
df_ranker_train['n_sold_category'].fillna(0, inplace=True)

df_ranker_train.head(2)
# Out:
#    user_id  item_id    item_score  target  manufacturer department     brand  \
# 0     1827   865334  11168.201881     0.0           870    DRUG GM  National
# 1     1827  1029743  11168.201881     1.0            69    GROCERY   Private
#
#         commodity_desc     sub_commodity_desc curr_size_of_product  ...  \
# 0            LAXATIVES              LAXATIVES                       ...
# 1  FLUID MILK PRODUCTS  FLUID MILK WHITE ONLY                 1 GA  ...
#
#   marital_status_code income_desc homeowner_desc hh_comp_desc  \
# 0                 NaN         NaN            NaN          NaN
# 1                 NaN         NaN            NaN          NaN
#
#   household_size_desc kid_category_desc avg_price  n_sold_category  \
# 0                 NaN               NaN  2.208947              2.0
# 1                 NaN               NaN  2.208947             25.0
#
#    avg_transaction_category  Missing n_sold_category
# 0                    1.0000                        0
# 1                    2.2408                        0
#
# [2 rows x 21 columns]

# %%
# Средняя сумма покупки в категории
department_sales = data_department.groupby('department')['sales_value'].mean().reset_index()
department_sales.rename(columns={'sales_value': 'mean_sales_value_category'}, inplace=True)
department_sales.tail(2)

n_weeks = data_department['week_no'].max() - data_department['week_no'].min() + 1

# Количество покупок юзером конкретной категории в неделю
users_department = data_department.groupby([USER_COL, 'department'])['quantity'].sum().reset_index()
users_department['quantity'] /= n_weeks
users_department.rename(columns={'quantity': 'n_sold_category_user_week'}, inplace=True)

df_ranker_train = df_ranker_train.merge(department_sales, on='department', how='left')
df_ranker_train = df_ranker_train.merge(users_department, on=[USER_COL, 'department'], how='left')
df_ranker_train.head(2)
# Out:
#    user_id  item_id    item_score  target  manufacturer department     brand  \
# 0     1827   865334  11168.201881     0.0           870    DRUG GM  National
# 1     1827  1029743  11168.201881     1.0            69    GROCERY   Private
#
#         commodity_desc     sub_commodity_desc curr_size_of_product  ...  \
# 0            LAXATIVES              LAXATIVES                       ...
# 1  FLUID MILK PRODUCTS  FLUID MILK WHITE ONLY                 1 GA  ...
#
#   homeowner_desc hh_comp_desc household_size_desc kid_category_desc avg_price  \
# 0            NaN          NaN                 NaN               NaN  2.208947
# 1            NaN          NaN                 NaN               NaN  2.208947
#
#   n_sold_category avg_transaction_category  Missing n_sold_category  \
# 0             2.0                   1.0000                        0
# 1            25.0                   2.2408                        0
#
#    mean_sales_value_category  n_sold_category_user_week
# 0                   3.994219                        0.4
# 1                   2.541433                        5.0
#
# [2 rows x 23 columns]

# %%
# Цена
items_sales = data_department.groupby(ITEM_COL)[['sales_value', 'quantity']].sum().reset_index()
items_sales['price'] = items_sales['sales_value'] / items_sales['quantity']
items_sales['price'].fillna(0, inplace=True)

# Количество покупок товара в неделю
items_sales['quantity_per_week'] = items_sales['quantity'] / n_weeks


df_ranker_train = df_ranker_train.merge(items_sales[[ITEM_COL,'price', 'quantity_per_week']],
                                        on=ITEM_COL, how='left')

df_ranker_train['Missing price'] = 0
df_ranker_train.loc[df_ranker_train['price'].isna(), 'Missing price'] = 1
df_ranker_train['price'].fillna(0, inplace=True)

df_ranker_train['Missing quantity per week'] = 0
df_ranker_train.loc[df_ranker_train['quantity_per_week'].isna(), 'Missing quantity per week'] = 1
df_ranker_train['quantity_per_week'].fillna(0, inplace=True)

df_ranker_train.head()
# Out:
#    user_id  item_id     item_score  target  manufacturer department     brand  \
# 0     1827   865334   1.116820e+04     0.0           870    DRUG GM  National
# 1     1827  1029743   1.116820e+04     1.0            69    GROCERY   Private
# 2     1827  1106523 -1.797693e+308     0.0            69    GROCERY   Private
# 3     1827  5569230 -1.797693e+308     0.0          1208    GROCERY  National
# 4     1827   916122 -1.797693e+308     0.0          4314       MEAT  National
#
#         commodity_desc              sub_commodity_desc curr_size_of_product  \
# 0            LAXATIVES                       LAXATIVES
# 1  FLUID MILK PRODUCTS           FLUID MILK WHITE ONLY                 1 GA
# 2  FLUID MILK PRODUCTS           FLUID MILK WHITE ONLY                 1 GA
# 3          SOFT DRINKS  SOFT DRINKS 12/18&15PK CAN CAR                12 OZ
# 4              CHICKEN         CHICKEN BREAST BONELESS
#
#    ... avg_price n_sold_category avg_transaction_category  \
# 0  ...  2.208947             2.0                   1.0000
# 1  ...  2.208947            25.0                   2.2408
# 2  ...  2.208947            25.0                   2.2408
# 3  ...  2.208947            25.0                   2.2408
# 4  ...  2.208947             0.0                      NaN
#
#   Missing n_sold_category mean_sales_value_category n_sold_category_user_week  \
# 0                       0                  3.994219                       0.4
# 1                       0                  2.541433                       5.0
# 2                       0                  2.541433                       5.0
# 3                       0                  2.541433                       5.0
# 4                       1                  6.552912                       NaN
#
#       price  quantity_per_week  Missing price  Missing quantity per week
# 0  0.000000                0.0              1                          1
# 1  2.424173              198.4              0                          0
# 2  2.454024              132.2              0                          0
# 3  4.180207               38.6              0                          0
# 4  3.782692               88.4              0                          0
#
# [5 rows x 27 columns]

# %%
# Количество уникальных магазинов, в которых продавался товар
items_stores = data_department.groupby(ITEM_COL)['store_id'].nunique().reset_index()
items_stores.rename(columns={'store_id': 'n_unique_stores'}, inplace=True)
df_ranker_train = df_ranker_train.merge(items_stores, on=ITEM_COL, how='left')

df_ranker_train.head(2)
# Out:
#    user_id  item_id    item_score  target  manufacturer department     brand  \
# 0     1827   865334  11168.201881     0.0           870    DRUG GM  National
# 1     1827  1029743  11168.201881     1.0            69    GROCERY   Private
#
#         commodity_desc     sub_commodity_desc curr_size_of_product  ...  \
# 0            LAXATIVES              LAXATIVES                       ...
# 1  FLUID MILK PRODUCTS  FLUID MILK WHITE ONLY                 1 GA  ...
#
#   n_sold_category avg_transaction_category Missing n_sold_category  \
# 0             2.0                   1.0000                       0
# 1            25.0                   2.2408                       0
#
#   mean_sales_value_category n_sold_category_user_week     price  \
# 0                  3.994219                       0.4  0.000000
# 1                  2.541433                       5.0  2.424173
#
#   quantity_per_week  Missing price  Missing quantity per week  n_unique_stores
# 0               0.0              1                          1              NaN
# 1             198.4              0                          0            106.0
#
# [2 rows x 28 columns]

# %%
# Среднее количество транзакций клиента в неделю
users_transactions = data_department.groupby(USER_COL)[ITEM_COL].count().reset_index()
users_transactions.rename(columns={'item_id': 'n_transactions_per_week'}, inplace=True)
users_transactions['n_transactions_per_week'] /= n_weeks


df_ranker_train = df_ranker_train.merge(users_transactions, on=USER_COL, how='left')

df_ranker_train.tail(2)
# Out:
#         user_id  item_id     item_score  target  manufacturer  department  \
# 209498     1745   944836 -1.797693e+308     0.0          5154        MEAT
# 209499     1745  8065410 -1.797693e+308     0.0           397  MEAT-PCKGD
#
#            brand commodity_desc sub_commodity_desc curr_size_of_product  ...  \
# 209498  National           BEEF              ANGUS                 1 LB  ...
# 209499  National          BACON            ECONOMY                16 OZ  ...
#
#        avg_transaction_category Missing n_sold_category  \
# 209498                      NaN                       1
# 209499                     2.99                       0
#
#        mean_sales_value_category n_sold_category_user_week     price  \
# 209498                  6.552912                       NaN  3.966471
# 209499                  3.828210                       0.4  2.753881
#
#        quantity_per_week Missing price  Missing quantity per week  \
# 209498              13.6             0                          0
# 209499              13.4             0                          0
#
#         n_unique_stores  n_transactions_per_week
# 209498             26.0                      0.6
# 209499             32.0                      0.6
#
# [2 rows x 29 columns]

# %%
# Средний чек
users_sales = data_train_ranker.groupby(USER_COL)['sales_value'].mean().reset_index()
users_sales.rename(columns={'sales_value': 'avg_cheque'}, inplace=True)
df_ranker_train = df_ranker_train.merge(users_sales[['user_id', 'avg_cheque']], on='user_id', how='left')
df_ranker_train.head(2)
# Out:
#    user_id  item_id    item_score  target  manufacturer department     brand  \
# 0     1827   865334  11168.201881     0.0           870    DRUG GM  National
# 1     1827  1029743  11168.201881     1.0            69    GROCERY   Private
#
#         commodity_desc     sub_commodity_desc curr_size_of_product  ...  \
# 0            LAXATIVES              LAXATIVES                       ...
# 1  FLUID MILK PRODUCTS  FLUID MILK WHITE ONLY                 1 GA  ...
#
#   Missing n_sold_category mean_sales_value_category n_sold_category_user_week  \
# 0                       0                  3.994219                       0.4
# 1                       0                  2.541433                       5.0
#
#       price quantity_per_week Missing price Missing quantity per week  \
# 0  0.000000               0.0             1                         1
# 1  2.424173             198.4             0                         0
#
#    n_unique_stores  n_transactions_per_week  avg_cheque
# 0              NaN                      6.0       2.798
# 1            106.0                      6.0       2.798
#
# [2 rows x 30 columns]

# %%
# Среднее количество уникальных категорий в корзине
users_baskets = data_department.groupby([USER_COL, 'basket_id'])['department'].nunique().reset_index()
users_baskets = users_baskets.groupby(USER_COL)['department'].mean().reset_index()
users_baskets.rename(columns={'department': 'avg_basket_department'}, inplace=True)
df_ranker_train = df_ranker_train.merge(users_baskets[['user_id', 'avg_basket_department']], on='user_id', how='left')
df_ranker_train.head(2)
# Out:
#    user_id  item_id    item_score  target  manufacturer department     brand  \
# 0     1827   865334  11168.201881     0.0           870    DRUG GM  National
# 1     1827  1029743  11168.201881     1.0            69    GROCERY   Private
#
#         commodity_desc     sub_commodity_desc curr_size_of_product  ...  \
# 0            LAXATIVES              LAXATIVES                       ...
# 1  FLUID MILK PRODUCTS  FLUID MILK WHITE ONLY                 1 GA  ...
#
#   mean_sales_value_category n_sold_category_user_week     price  \
# 0                  3.994219                       0.4  0.000000
# 1                  2.541433                       5.0  2.424173
#
#   quantity_per_week Missing price Missing quantity per week n_unique_stores  \
# 0               0.0             1                         1             NaN
# 1             198.4             0                         0           106.0
#
#    n_transactions_per_week  avg_cheque  avg_basket_department
# 0                      6.0       2.798                    2.4
# 1                      6.0       2.798                    2.4
#
# [2 rows x 31 columns]

# %%
# Признак, отражающий средний интервал между покупками пользователя.

users_days = data_department.groupby(USER_COL)['day'].unique().reset_index()
users_days['day'] = users_days['day'].apply(lambda x: sorted(x))
users_days.head()
# Out:
#    user_id                                                day
# 0        1                     [606, 608, 610, 620, 622, 632]
# 1        2                               [608, 614, 620, 622]
# 2        4                                    [605, 617, 627]
# 3        6  [603, 607, 610, 611, 616, 619, 620, 624, 627, ...
# 4        7                          [606, 610, 614, 623, 629]

# %%
def avg_ndays(days):
    diff = 0
    if len(days) > 1:
        for i in range(len(days) - 1):
            diff += days[i+1] - days[i]
        return diff / (len(days) - 1)
    else:
        return 0
    
users_days['avg_interval'] = users_days['day'].apply(avg_ndays)

df_ranker_train = df_ranker_train.merge(users_days[['user_id', 'avg_interval']], on='user_id', how='left')
df_ranker_train.head(2)
# Out:
#    user_id  item_id    item_score  target  manufacturer department     brand  \
# 0     1827   865334  11168.201881     0.0           870    DRUG GM  National
# 1     1827  1029743  11168.201881     1.0            69    GROCERY   Private
#
#         commodity_desc     sub_commodity_desc curr_size_of_product  ...  \
# 0            LAXATIVES              LAXATIVES                       ...
# 1  FLUID MILK PRODUCTS  FLUID MILK WHITE ONLY                 1 GA  ...
#
#   n_sold_category_user_week     price quantity_per_week Missing price  \
# 0                       0.4  0.000000               0.0             1
# 1                       5.0  2.424173             198.4             0
#
#   Missing quantity per week n_unique_stores n_transactions_per_week  \
# 0                         1             NaN                     6.0
# 1                         0           106.0                     6.0
#
#    avg_cheque  avg_basket_department  avg_interval
# 0       2.798                    2.4           7.0
# 1       2.798                    2.4           7.0
#
# [2 rows x 32 columns]

# %% [markdown]
# ### Построим признак, в котором будет закодировано место товара в пяти последних покупках клиента.

# %%
users_items = data_train_ranker.groupby(USER_COL)[ITEM_COL].apply(list).reset_index()
users_items['item_id'] = users_items['item_id'].apply(lambda x: x[-5:])
users_items.head()
# Out:
#    user_id                                            item_id
# 0        1     [5577022, 8293439, 9526676, 9527558, 10149640]
# 1        2  [7407562, 10149597, 13776981, 15572067, 17215077]
# 2        4       [963365, 1038692, 1133312, 5570830, 7431408]
# 3        6       [1099058, 895268, 1017061, 1082185, 1119051]
# 4        7  [9837501, 12524016, 13072715, 13987153, 13987338]

# %%
def code_last_sales(x, df=users_items):
    last_sales = df.loc[df['user_id'] == x[0], 'item_id'].item()
    code = str()
    last_sales.reverse()
    for item in last_sales:
        code += '1' if item == x[1] else '0'
    return code

df_ranker_train['Last5sales'] = df_ranker_train[[USER_COL, ITEM_COL]].apply(code_last_sales, axis=1)
df_ranker_train.head(2)
# Out:
#    user_id  item_id    item_score  target  manufacturer department     brand  \
# 0     1827   865334  11168.201881     0.0           870    DRUG GM  National
# 1     1827  1029743  11168.201881     1.0            69    GROCERY   Private
#
#         commodity_desc     sub_commodity_desc curr_size_of_product  ...  \
# 0            LAXATIVES              LAXATIVES                       ...
# 1  FLUID MILK PRODUCTS  FLUID MILK WHITE ONLY                 1 GA  ...
#
#       price quantity_per_week Missing price Missing quantity per week  \
# 0  0.000000               0.0             1                         1
# 1  2.424173             198.4             0                         0
#
#   n_unique_stores n_transactions_per_week avg_cheque  avg_basket_department  \
# 0             NaN                     6.0      2.798                    2.4
# 1           106.0                     6.0      2.798                    2.4
#
#    avg_interval  Last5sales
# 0           7.0       00000
# 1           7.0       10000
#
# [2 rows x 33 columns]

# %% [markdown]
# #### Построим модель Word2Vec для получения эмбеддингов товаров, а затем посчитаем длину вектора, описывающего каждый товар, и расстояние от word2vec эмбеддинга товара до среднего эмбеддинга товаров, купленных клиентом.

# %%
df_ = data_train_ranker.groupby(USER_COL)[ITEM_COL].unique().reset_index()
df_.head()
# Out:
#    user_id                                            item_id
# 0        1  [1005186, 907466, 909497, 940947, 963542, 1067...
# 1        2  [15830248, 838136, 839656, 861272, 866211, 870...
# 2        4  [883932, 970760, 1035676, 1055863, 1097610, 67...
# 3        6  [873654, 994928, 1098844, 1122879, 8357613, 98...
# 4        7  [836281, 843306, 845294, 914190, 920456, 93886...

# %%
purchases = []

for user in df_['user_id']:
    purchases.append([str(item) for item in df_[df_['user_id'] == user].item_id.values[0]])
    
print(f"Total # of Sessions: {len(purchases)}")
# Out:
# Total # of Sessions: 2095

# %%
w2v_model = Word2Vec(min_count=1, vector_size=100, sg=1, workers=3)
w2v_model.build_vocab(purchases, progress_per=100)
w2v_model.train(purchases, total_examples=w2v_model.corpus_count, epochs=10, report_delay=1)
# Out:
# (1209182, 1214930)

# %%
def word2vec_len(itemid):
    try:
        return sum([i**2 for i in w2v_model.wv[str(itemid)]])
    except:
        return -1

df_ranker_train['Word2Vec_length'] = df_ranker_train[ITEM_COL].apply(lambda x: word2vec_len(x))
df_ranker_train.head(2)
# Out:
#    user_id  item_id    item_score  target  manufacturer department     brand  \
# 0     1827   865334  11168.201881     0.0           870    DRUG GM  National
# 1     1827  1029743  11168.201881     1.0            69    GROCERY   Private
#
#         commodity_desc     sub_commodity_desc curr_size_of_product  ...  \
# 0            LAXATIVES              LAXATIVES                       ...
# 1  FLUID MILK PRODUCTS  FLUID MILK WHITE ONLY                 1 GA  ...
#
#   quantity_per_week Missing price Missing quantity per week n_unique_stores  \
# 0               0.0             1                         1             NaN
# 1             198.4             0                         0           106.0
#
#   n_transactions_per_week avg_cheque avg_basket_department  avg_interval  \
# 0                     6.0      2.798                   2.4           7.0
# 1                     6.0      2.798                   2.4           7.0
#
#    Last5sales  Word2Vec_length
# 0       00000         -1.00000
# 1       10000          7.04723
#
# [2 rows x 34 columns]

# %%
def avg_word2vec(items):
    return sum([w2v_model.wv[str(item)] for item in items]) / len(items)

df_['Avg_Word2Vec'] = df_[ITEM_COL].apply(avg_word2vec)
df_.head()
# Out:
#    user_id                                            item_id  \
# 0        1  [1005186, 907466, 909497, 940947, 963542, 1067...
# 1        2  [15830248, 838136, 839656, 861272, 866211, 870...
# 2        4  [883932, 970760, 1035676, 1055863, 1097610, 67...
# 3        6  [873654, 994928, 1098844, 1122879, 8357613, 98...
# 4        7  [836281, 843306, 845294, 914190, 920456, 93886...
#
#                                         Avg_Word2Vec
# 0  [-0.10414569, 0.18625408, 0.20200114, 0.032644...
# 1  [-0.09097483, 0.25257882, 0.19576512, 0.071112...
# 2  [-0.09394967, 0.23061757, 0.19857715, 0.042350...
# 3  [-0.08779907, 0.22913173, 0.19350904, 0.047811...
# 4  [-0.10020275, 0.21766569, 0.20840691, 0.030765...

# %%
def get_w2v_distance(x, df=df_):
    avg_w2v = df.loc[df_[USER_COL] == x[0], 'Avg_Word2Vec'].item()
    try:
        return sum((w2v_model.wv[str(x[1])] - avg_w2v) ** 2)
    except:
        return -1
    
df_ranker_train['Word2Vec_distance_from_avg'] = df_ranker_train[[USER_COL, ITEM_COL]].\
                                                apply(get_w2v_distance, axis=1)
df_ranker_train.head(2)
# Out:
#    user_id  item_id    item_score  target  manufacturer department     brand  \
# 0     1827   865334  11168.201881     0.0           870    DRUG GM  National
# 1     1827  1029743  11168.201881     1.0            69    GROCERY   Private
#
#         commodity_desc     sub_commodity_desc curr_size_of_product  ...  \
# 0            LAXATIVES              LAXATIVES                       ...
# 1  FLUID MILK PRODUCTS  FLUID MILK WHITE ONLY                 1 GA  ...
#
#   Missing price Missing quantity per week n_unique_stores  \
# 0             1                         1             NaN
# 1             0                         0           106.0
#
#   n_transactions_per_week avg_cheque avg_basket_department avg_interval  \
# 0                     6.0      2.798                   2.4          7.0
# 1                     6.0      2.798                   2.4          7.0
#
#    Last5sales  Word2Vec_length  Word2Vec_distance_from_avg
# 0       00000         -1.00000                   -1.000000
# 1       10000          7.04723                    3.347656
#
# [2 rows x 35 columns]

# %% [markdown]
# ### 6. Построение модели второго уровня.
#
# Теперь обучим модель ранжирования и посчитаем метрики.

# %%
X_train = df_ranker_train.drop(['target', 
                                'Missing n_sold_category', 
                                'n_sold_category_user_week', 
                                'mean_sales_value_category',], axis=1)
y_train = df_ranker_train['target']

# %%
cat_feats = ['manufacturer', 
             'department', 
             'brand', 
             'commodity_desc',
             'sub_commodity_desc',
             'curr_size_of_product',
             'age_desc',
             'marital_status_code',
             'income_desc',
             'homeowner_desc',
             'hh_comp_desc',
             'household_size_desc',
             'kid_category_desc',
             'Missing price',
             'Missing quantity per week',
             'Last5sales',
            ]


for column in cat_feats:
    X_train[column].fillna(0, inplace=True)
    
X_train[cat_feats] = X_train[cat_feats].astype('category')

# %%
# %%time
cb = CatBoostClassifier(learning_rate=0.1,
                        max_depth=12,
                        n_estimators=500,
                        random_state=42, 
                        cat_features=cat_feats, 
                        silent=False)

cb.fit(X_train, y_train)

train_preds = cb.predict_proba(X_train)
# Out:
# 0:	learn: 0.5318703	total: 533ms	remaining: 4m 25s
# 1:	learn: 0.4297466	total: 574ms	remaining: 2m 22s
# 2:	learn: 0.3343490	total: 1.37s	remaining: 3m 47s
# 3:	learn: 0.2724333	total: 1.72s	remaining: 3m 33s
# 4:	learn: 0.2356844	total: 1.85s	remaining: 3m 3s
# 5:	learn: 0.1954762	total: 2.84s	remaining: 3m 54s
# 6:	learn: 0.1696132	total: 3.05s	remaining: 3m 34s
# 7:	learn: 0.1542356	total: 3.16s	remaining: 3m 14s
# 8:	learn: 0.1414689	total: 4s	remaining: 3m 38s
# 9:	learn: 0.1341344	total: 4.27s	remaining: 3m 29s
# 10:	learn: 0.1295019	total: 4.35s	remaining: 3m 13s
# 11:	learn: 0.1246707	total: 5.18s	remaining: 3m 30s
# 12:	learn: 0.1205085	total: 5.91s	remaining: 3m 41s
# 13:	learn: 0.1177923	total: 6.75s	remaining: 3m 54s
# 14:	learn: 0.1155156	total: 7.55s	remaining: 4m 4s
# 15:	learn: 0.1134816	total: 8.28s	remaining: 4m 10s
# 16:	learn: 0.1114508	total: 9.12s	remaining: 4m 19s
# 17:	learn: 0.1099796	total: 9.97s	remaining: 4m 27s
# 18:	learn: 0.1091563	total: 10.2s	remaining: 4m 17s
# 19:	learn: 0.1077443	total: 11.1s	remaining: 4m 26s
# 20:	learn: 0.1069078	total: 11.9s	remaining: 4m 30s
# 21:	learn: 0.1066844	total: 12s	remaining: 4m 20s
# 22:	learn: 0.1057540	total: 12.8s	remaining: 4m 26s
# 23:	learn: 0.1049910	total: 13.7s	remaining: 4m 32s
# 24:	learn: 0.1043387	total: 14.6s	remaining: 4m 37s
# 25:	learn: 0.1035700	total: 15.4s	remaining: 4m 40s
# 26:	learn: 0.1029286	total: 16.2s	remaining: 4m 43s
# 27:	learn: 0.1022485	total: 17.1s	remaining: 4m 48s
# 28:	learn: 0.1015578	total: 18s	remaining: 4m 52s
# 29:	learn: 0.1008092	total: 18.9s	remaining: 4m 56s
# 30:	learn: 0.1002573	total: 19.8s	remaining: 5m
# 31:	learn: 0.0999485	total: 20.8s	remaining: 5m 4s
# 32:	learn: 0.0995340	total: 21.7s	remaining: 5m 6s
# 33:	learn: 0.0990220	total: 22.5s	remaining: 5m 8s
# 34:	learn: 0.0986117	total: 23.5s	remaining: 5m 12s
# 35:	learn: 0.0984067	total: 24.4s	remaining: 5m 14s
# 36:	learn: 0.0982708	total: 25.5s	remaining: 5m 18s
# 37:	learn: 0.0976493	total: 26.5s	remaining: 5m 21s
# 38:	learn: 0.0974781	total: 27.4s	remaining: 5m 24s
# 39:	learn: 0.0972898	total: 28.3s	remaining: 5m 25s
# 40:	learn: 0.0968705	total: 29.4s	remaining: 5m 28s
# 41:	learn: 0.0966538	total: 30.5s	remaining: 5m 32s
# 42:	learn: 0.0963640	total: 31.5s	remaining: 5m 34s
# 43:	learn: 0.0959166	total: 32.5s	remaining: 5m 36s
# 44:	learn: 0.0958566	total: 33.6s	remaining: 5m 39s
# 45:	learn: 0.0952400	total: 34.5s	remaining: 5m 40s
# 46:	learn: 0.0949764	total: 35.4s	remaining: 5m 41s
# 47:	learn: 0.0946951	total: 36.4s	remaining: 5m 42s
# 48:	learn: 0.0944309	total: 37.3s	remaining: 5m 43s
# 49:	learn: 0.0941797	total: 38.3s	remaining: 5m 45s
# 50:	learn: 0.0938140	total: 39.3s	remaining: 5m 45s
# 51:	learn: 0.0935290	total: 40.2s	remaining: 5m 46s
# 52:	learn: 0.0932595	total: 41.1s	remaining: 5m 46s
# 53:	learn: 0.0930705	total: 42.1s	remaining: 5m 47s
# 54:	learn: 0.0928995	total: 43.1s	remaining: 5m 48s
# 55:	learn: 0.0927212	total: 44.2s	remaining: 5m 50s
# 56:	learn: 0.0923581	total: 45.1s	remaining: 5m 50s
# 57:	learn: 0.0918870	total: 46.1s	remaining: 5m 51s
# 58:	learn: 0.0915046	total: 47.1s	remaining: 5m 52s
# 59:	learn: 0.0911737	total: 48.2s	remaining: 5m 53s
# 60:	learn: 0.0911286	total: 49.3s	remaining: 5m 55s
# 61:	learn: 0.0909470	total: 50.4s	remaining: 5m 55s
# 62:	learn: 0.0909452	total: 50.5s	remaining: 5m 49s
# 63:	learn: 0.0909342	total: 50.6s	remaining: 5m 44s
# 64:	learn: 0.0904736	total: 51.6s	remaining: 5m 45s
# 65:	learn: 0.0904636	total: 51.7s	remaining: 5m 40s
# 66:	learn: 0.0904524	total: 51.9s	remaining: 5m 35s
# 67:	learn: 0.0903206	total: 52.9s	remaining: 5m 36s
# 68:	learn: 0.0900705	total: 53.9s	remaining: 5m 36s
# 69:	learn: 0.0899201	total: 54.8s	remaining: 5m 36s
# 70:	learn: 0.0899041	total: 55s	remaining: 5m 32s
# 71:	learn: 0.0898294	total: 56.1s	remaining: 5m 33s
# 72:	learn: 0.0898059	total: 56.2s	remaining: 5m 28s
# 73:	learn: 0.0894725	total: 57.2s	remaining: 5m 29s
# 74:	learn: 0.0891949	total: 58.3s	remaining: 5m 30s
# 75:	learn: 0.0891942	total: 58.3s	remaining: 5m 25s
# 76:	learn: 0.0889362	total: 59.2s	remaining: 5m 25s
# 77:	learn: 0.0886933	total: 1m	remaining: 5m 26s
# 78:	learn: 0.0883206	total: 1m 1s	remaining: 5m 26s
# 79:	learn: 0.0879937	total: 1m 2s	remaining: 5m 26s
# 80:	learn: 0.0877737	total: 1m 3s	remaining: 5m 27s
# 81:	learn: 0.0875585	total: 1m 4s	remaining: 5m 27s
# 82:	learn: 0.0874508	total: 1m 5s	remaining: 5m 28s
# 83:	learn: 0.0874430	total: 1m 5s	remaining: 5m 25s
# 84:	learn: 0.0872257	total: 1m 6s	remaining: 5m 25s
# 85:	learn: 0.0870460	total: 1m 7s	remaining: 5m 26s
# 86:	learn: 0.0869789	total: 1m 8s	remaining: 5m 26s
# 87:	learn: 0.0868882	total: 1m 9s	remaining: 5m 27s
# 88:	learn: 0.0864710	total: 1m 10s	remaining: 5m 27s
# 89:	learn: 0.0861958	total: 1m 11s	remaining: 5m 27s
# 90:	learn: 0.0861169	total: 1m 13s	remaining: 5m 28s
# 91:	learn: 0.0859803	total: 1m 14s	remaining: 5m 28s
# 92:	learn: 0.0859745	total: 1m 14s	remaining: 5m 25s
# 93:	learn: 0.0858351	total: 1m 15s	remaining: 5m 26s
# 94:	learn: 0.0857342	total: 1m 16s	remaining: 5m 26s
# 95:	learn: 0.0856499	total: 1m 17s	remaining: 5m 26s
# 96:	learn: 0.0855554	total: 1m 18s	remaining: 5m 27s
# 97:	learn: 0.0855423	total: 1m 19s	remaining: 5m 24s
# 98:	learn: 0.0855420	total: 1m 19s	remaining: 5m 20s
# 99:	learn: 0.0852139	total: 1m 20s	remaining: 5m 20s
# 100:	learn: 0.0852073	total: 1m 20s	remaining: 5m 18s
# 101:	learn: 0.0850170	total: 1m 21s	remaining: 5m 18s
# 102:	learn: 0.0849366	total: 1m 22s	remaining: 5m 19s
# 103:	learn: 0.0847030	total: 1m 23s	remaining: 5m 19s
# 104:	learn: 0.0846348	total: 1m 25s	remaining: 5m 19s
# 105:	learn: 0.0845180	total: 1m 25s	remaining: 5m 19s
# 106:	learn: 0.0841447	total: 1m 27s	remaining: 5m 19s
# 107:	learn: 0.0841376	total: 1m 28s	remaining: 5m 19s
# 108:	learn: 0.0841373	total: 1m 28s	remaining: 5m 16s
# 109:	learn: 0.0839552	total: 1m 29s	remaining: 5m 15s
# 110:	learn: 0.0838915	total: 1m 30s	remaining: 5m 15s
# 111:	learn: 0.0838662	total: 1m 31s	remaining: 5m 15s
# 112:	learn: 0.0836354	total: 1m 32s	remaining: 5m 15s
# 113:	learn: 0.0834979	total: 1m 33s	remaining: 5m 15s
# 114:	learn: 0.0832746	total: 1m 34s	remaining: 5m 15s
# 115:	learn: 0.0831206	total: 1m 35s	remaining: 5m 15s
# 116:	learn: 0.0830467	total: 1m 36s	remaining: 5m 16s
# 117:	learn: 0.0825859	total: 1m 37s	remaining: 5m 15s
# 118:	learn: 0.0824437	total: 1m 38s	remaining: 5m 15s
# 119:	learn: 0.0824366	total: 1m 39s	remaining: 5m 13s
# 120:	learn: 0.0824281	total: 1m 40s	remaining: 5m 13s
# 121:	learn: 0.0822628	total: 1m 41s	remaining: 5m 13s
# 122:	learn: 0.0820964	total: 1m 42s	remaining: 5m 13s
# 123:	learn: 0.0818173	total: 1m 43s	remaining: 5m 12s
# 124:	learn: 0.0814172	total: 1m 44s	remaining: 5m 12s
# 125:	learn: 0.0811456	total: 1m 45s	remaining: 5m 11s
# 126:	learn: 0.0808021	total: 1m 46s	remaining: 5m 11s
# 127:	learn: 0.0803343	total: 1m 47s	remaining: 5m 11s
# 128:	learn: 0.0800417	total: 1m 48s	remaining: 5m 10s
# 129:	learn: 0.0797812	total: 1m 49s	remaining: 5m 10s
# 130:	learn: 0.0794682	total: 1m 50s	remaining: 5m 10s
# 131:	learn: 0.0791844	total: 1m 51s	remaining: 5m 9s
# 132:	learn: 0.0789113	total: 1m 52s	remaining: 5m 9s
# 133:	learn: 0.0788037	total: 1m 53s	remaining: 5m 8s
# 134:	learn: 0.0783019	total: 1m 54s	remaining: 5m 8s
# 135:	learn: 0.0780530	total: 1m 55s	remaining: 5m 8s
# 136:	learn: 0.0777889	total: 1m 56s	remaining: 5m 7s
# 137:	learn: 0.0775180	total: 1m 56s	remaining: 5m 6s
# 138:	learn: 0.0773404	total: 1m 57s	remaining: 5m 6s
# 139:	learn: 0.0772206	total: 1m 58s	remaining: 5m 5s
# 140:	learn: 0.0770462	total: 1m 59s	remaining: 5m 5s
# 141:	learn: 0.0769898	total: 2m	remaining: 5m 4s
# 142:	learn: 0.0768473	total: 2m 2s	remaining: 5m 4s
# 143:	learn: 0.0767370	total: 2m 2s	remaining: 5m 3s
# 144:	learn: 0.0766838	total: 2m 3s	remaining: 5m 3s
# 145:	learn: 0.0765869	total: 2m 5s	remaining: 5m 3s
# 146:	learn: 0.0764032	total: 2m 6s	remaining: 5m 2s
# 147:	learn: 0.0760961	total: 2m 6s	remaining: 5m 2s
# 148:	learn: 0.0757230	total: 2m 8s	remaining: 5m 1s
# 149:	learn: 0.0753734	total: 2m 9s	remaining: 5m 1s
# 150:	learn: 0.0750892	total: 2m 10s	remaining: 5m
# 151:	learn: 0.0750253	total: 2m 11s	remaining: 5m
# 152:	learn: 0.0749226	total: 2m 12s	remaining: 5m
# 153:	learn: 0.0747007	total: 2m 13s	remaining: 4m 59s
# 154:	learn: 0.0744512	total: 2m 14s	remaining: 4m 58s
# 155:	learn: 0.0743229	total: 2m 15s	remaining: 4m 57s
# 156:	learn: 0.0740655	total: 2m 16s	remaining: 4m 57s
# 157:	learn: 0.0739536	total: 2m 17s	remaining: 4m 56s
# 158:	learn: 0.0737952	total: 2m 18s	remaining: 4m 56s
# 159:	learn: 0.0734123	total: 2m 19s	remaining: 4m 55s
# 160:	learn: 0.0731432	total: 2m 19s	remaining: 4m 54s
# 161:	learn: 0.0729070	total: 2m 20s	remaining: 4m 53s
# 162:	learn: 0.0728035	total: 2m 21s	remaining: 4m 52s
# 163:	learn: 0.0725565	total: 2m 22s	remaining: 4m 52s
# 164:	learn: 0.0722995	total: 2m 23s	remaining: 4m 51s
# 165:	learn: 0.0719837	total: 2m 24s	remaining: 4m 51s
# 166:	learn: 0.0716118	total: 2m 26s	remaining: 4m 51s
# 167:	learn: 0.0714232	total: 2m 27s	remaining: 4m 50s
# 168:	learn: 0.0712798	total: 2m 28s	remaining: 4m 49s
# 169:	learn: 0.0709903	total: 2m 28s	remaining: 4m 49s
# 170:	learn: 0.0708703	total: 2m 29s	remaining: 4m 48s
# 171:	learn: 0.0707586	total: 2m 30s	remaining: 4m 47s
# 172:	learn: 0.0704925	total: 2m 31s	remaining: 4m 46s
# 173:	learn: 0.0703308	total: 2m 32s	remaining: 4m 46s
# 174:	learn: 0.0702995	total: 2m 33s	remaining: 4m 45s
# 175:	learn: 0.0700504	total: 2m 34s	remaining: 4m 44s
# 176:	learn: 0.0699549	total: 2m 35s	remaining: 4m 44s
# 177:	learn: 0.0697391	total: 2m 36s	remaining: 4m 43s
# 178:	learn: 0.0696158	total: 2m 37s	remaining: 4m 42s
# 179:	learn: 0.0693647	total: 2m 38s	remaining: 4m 41s
# 180:	learn: 0.0692231	total: 2m 39s	remaining: 4m 41s
# 181:	learn: 0.0691625	total: 2m 40s	remaining: 4m 40s
# 182:	learn: 0.0689347	total: 2m 41s	remaining: 4m 40s
# 183:	learn: 0.0687572	total: 2m 42s	remaining: 4m 39s
# 184:	learn: 0.0684411	total: 2m 43s	remaining: 4m 38s
# 185:	learn: 0.0683972	total: 2m 44s	remaining: 4m 38s
# 186:	learn: 0.0681337	total: 2m 45s	remaining: 4m 37s
# 187:	learn: 0.0679176	total: 2m 46s	remaining: 4m 36s
# 188:	learn: 0.0678686	total: 2m 47s	remaining: 4m 36s
# 189:	learn: 0.0677586	total: 2m 48s	remaining: 4m 35s
# 190:	learn: 0.0675423	total: 2m 49s	remaining: 4m 34s
# 191:	learn: 0.0673345	total: 2m 50s	remaining: 4m 33s
# 192:	learn: 0.0671160	total: 2m 51s	remaining: 4m 33s
# 193:	learn: 0.0670339	total: 2m 52s	remaining: 4m 32s
# 194:	learn: 0.0667854	total: 2m 53s	remaining: 4m 31s
# 195:	learn: 0.0666599	total: 2m 54s	remaining: 4m 31s
# 196:	learn: 0.0664949	total: 2m 55s	remaining: 4m 30s
# 197:	learn: 0.0664569	total: 2m 56s	remaining: 4m 29s
# 198:	learn: 0.0660386	total: 2m 57s	remaining: 4m 29s
# 199:	learn: 0.0656262	total: 2m 58s	remaining: 4m 28s
# 200:	learn: 0.0654158	total: 2m 59s	remaining: 4m 27s
# 201:	learn: 0.0653733	total: 3m	remaining: 4m 26s
# 202:	learn: 0.0653171	total: 3m 1s	remaining: 4m 26s
# 203:	learn: 0.0651493	total: 3m 2s	remaining: 4m 25s
# 204:	learn: 0.0650159	total: 3m 3s	remaining: 4m 24s
# 205:	learn: 0.0647645	total: 3m 4s	remaining: 4m 23s
# 206:	learn: 0.0643644	total: 3m 5s	remaining: 4m 22s
# 207:	learn: 0.0643094	total: 3m 6s	remaining: 4m 21s
# 208:	learn: 0.0641447	total: 3m 7s	remaining: 4m 21s
# 209:	learn: 0.0637691	total: 3m 8s	remaining: 4m 20s
# 210:	learn: 0.0636024	total: 3m 9s	remaining: 4m 19s
# 211:	learn: 0.0633127	total: 3m 10s	remaining: 4m 19s
# 212:	learn: 0.0632371	total: 3m 11s	remaining: 4m 18s
# 213:	learn: 0.0629199	total: 3m 12s	remaining: 4m 17s
# 214:	learn: 0.0627039	total: 3m 13s	remaining: 4m 16s
# 215:	learn: 0.0625380	total: 3m 14s	remaining: 4m 16s
# 216:	learn: 0.0621556	total: 3m 15s	remaining: 4m 15s
# 217:	learn: 0.0619908	total: 3m 16s	remaining: 4m 14s
# 218:	learn: 0.0618214	total: 3m 17s	remaining: 4m 13s
# 219:	learn: 0.0615195	total: 3m 18s	remaining: 4m 12s
# 220:	learn: 0.0612346	total: 3m 19s	remaining: 4m 12s
# 221:	learn: 0.0610623	total: 3m 20s	remaining: 4m 11s
# 222:	learn: 0.0608373	total: 3m 21s	remaining: 4m 10s
# 223:	learn: 0.0606988	total: 3m 22s	remaining: 4m 9s
# 224:	learn: 0.0606274	total: 3m 23s	remaining: 4m 8s
# 225:	learn: 0.0605876	total: 3m 24s	remaining: 4m 7s
# 226:	learn: 0.0603086	total: 3m 25s	remaining: 4m 7s
# 227:	learn: 0.0602753	total: 3m 26s	remaining: 4m 6s
# 228:	learn: 0.0601974	total: 3m 27s	remaining: 4m 5s
# 229:	learn: 0.0600903	total: 3m 28s	remaining: 4m 5s
# 230:	learn: 0.0599136	total: 3m 29s	remaining: 4m 4s
# 231:	learn: 0.0598741	total: 3m 30s	remaining: 4m 3s
# 232:	learn: 0.0598323	total: 3m 31s	remaining: 4m 2s
# 233:	learn: 0.0596587	total: 3m 32s	remaining: 4m 1s
# 234:	learn: 0.0596151	total: 3m 33s	remaining: 4m
# 235:	learn: 0.0594988	total: 3m 34s	remaining: 4m
# 236:	learn: 0.0591818	total: 3m 35s	remaining: 3m 59s
# 237:	learn: 0.0589501	total: 3m 36s	remaining: 3m 58s
# 238:	learn: 0.0589003	total: 3m 37s	remaining: 3m 57s
# 239:	learn: 0.0588736	total: 3m 38s	remaining: 3m 57s
# 240:	learn: 0.0588322	total: 3m 40s	remaining: 3m 56s
# 241:	learn: 0.0586584	total: 3m 41s	remaining: 3m 55s
# 242:	learn: 0.0584827	total: 3m 42s	remaining: 3m 54s
# 243:	learn: 0.0583549	total: 3m 43s	remaining: 3m 54s
# 244:	learn: 0.0581320	total: 3m 44s	remaining: 3m 53s
# 245:	learn: 0.0580683	total: 3m 45s	remaining: 3m 52s
# 246:	learn: 0.0577617	total: 3m 46s	remaining: 3m 51s
# 247:	learn: 0.0576161	total: 3m 46s	remaining: 3m 50s
# 248:	learn: 0.0575028	total: 3m 47s	remaining: 3m 49s
# 249:	learn: 0.0574175	total: 3m 48s	remaining: 3m 48s
# 250:	learn: 0.0573516	total: 3m 49s	remaining: 3m 47s
# 251:	learn: 0.0570628	total: 3m 50s	remaining: 3m 47s
# 252:	learn: 0.0569472	total: 3m 51s	remaining: 3m 46s
# 253:	learn: 0.0567780	total: 3m 52s	remaining: 3m 45s
# 254:	learn: 0.0567294	total: 3m 53s	remaining: 3m 44s
# 255:	learn: 0.0566388	total: 3m 54s	remaining: 3m 43s
# 256:	learn: 0.0562752	total: 3m 55s	remaining: 3m 42s
# 257:	learn: 0.0561346	total: 3m 56s	remaining: 3m 42s
# 258:	learn: 0.0559352	total: 3m 57s	remaining: 3m 41s
# 259:	learn: 0.0558062	total: 3m 58s	remaining: 3m 40s
# 260:	learn: 0.0555361	total: 3m 59s	remaining: 3m 39s
# 261:	learn: 0.0553232	total: 4m	remaining: 3m 38s
# 262:	learn: 0.0552204	total: 4m 1s	remaining: 3m 38s
# 263:	learn: 0.0551549	total: 4m 2s	remaining: 3m 37s
# 264:	learn: 0.0550446	total: 4m 3s	remaining: 3m 36s
# 265:	learn: 0.0549121	total: 4m 4s	remaining: 3m 35s
# 266:	learn: 0.0548762	total: 4m 5s	remaining: 3m 34s
# 267:	learn: 0.0547929	total: 4m 6s	remaining: 3m 33s
# 268:	learn: 0.0547148	total: 4m 7s	remaining: 3m 32s
# 269:	learn: 0.0546429	total: 4m 8s	remaining: 3m 32s
# 270:	learn: 0.0543361	total: 4m 10s	remaining: 3m 31s
# 271:	learn: 0.0541065	total: 4m 11s	remaining: 3m 30s
# 272:	learn: 0.0539889	total: 4m 12s	remaining: 3m 29s
# 273:	learn: 0.0538602	total: 4m 12s	remaining: 3m 28s
# 274:	learn: 0.0537707	total: 4m 14s	remaining: 3m 27s
# 275:	learn: 0.0535726	total: 4m 15s	remaining: 3m 26s
# 276:	learn: 0.0533416	total: 4m 16s	remaining: 3m 26s
# 277:	learn: 0.0532524	total: 4m 17s	remaining: 3m 25s
# 278:	learn: 0.0531314	total: 4m 18s	remaining: 3m 24s
# 279:	learn: 0.0530449	total: 4m 19s	remaining: 3m 23s
# 280:	learn: 0.0530162	total: 4m 20s	remaining: 3m 22s
# 281:	learn: 0.0529988	total: 4m 21s	remaining: 3m 22s
# 282:	learn: 0.0528934	total: 4m 22s	remaining: 3m 21s
# 283:	learn: 0.0528034	total: 4m 23s	remaining: 3m 20s
# 284:	learn: 0.0527615	total: 4m 24s	remaining: 3m 19s
# 285:	learn: 0.0527132	total: 4m 25s	remaining: 3m 18s
# 286:	learn: 0.0526481	total: 4m 26s	remaining: 3m 17s
# 287:	learn: 0.0524885	total: 4m 27s	remaining: 3m 16s
# 288:	learn: 0.0524614	total: 4m 28s	remaining: 3m 16s
# 289:	learn: 0.0524288	total: 4m 29s	remaining: 3m 15s
# 290:	learn: 0.0523754	total: 4m 30s	remaining: 3m 14s
# 291:	learn: 0.0522207	total: 4m 31s	remaining: 3m 13s
# 292:	learn: 0.0520757	total: 4m 33s	remaining: 3m 12s
# 293:	learn: 0.0519699	total: 4m 34s	remaining: 3m 12s
# 294:	learn: 0.0519259	total: 4m 35s	remaining: 3m 11s
# 295:	learn: 0.0518214	total: 4m 35s	remaining: 3m 10s
# 296:	learn: 0.0516523	total: 4m 37s	remaining: 3m 9s
# 297:	learn: 0.0516105	total: 4m 38s	remaining: 3m 8s
# 298:	learn: 0.0515640	total: 4m 39s	remaining: 3m 7s
# 299:	learn: 0.0514755	total: 4m 40s	remaining: 3m 6s
# 300:	learn: 0.0514403	total: 4m 41s	remaining: 3m 5s
# 301:	learn: 0.0513947	total: 4m 42s	remaining: 3m 5s
# 302:	learn: 0.0513700	total: 4m 43s	remaining: 3m 4s
# 303:	learn: 0.0512041	total: 4m 44s	remaining: 3m 3s
# 304:	learn: 0.0511519	total: 4m 45s	remaining: 3m 2s
# 305:	learn: 0.0508911	total: 4m 46s	remaining: 3m 1s
# 306:	learn: 0.0508399	total: 4m 47s	remaining: 3m
# 307:	learn: 0.0507902	total: 4m 48s	remaining: 2m 59s
# 308:	learn: 0.0507110	total: 4m 49s	remaining: 2m 58s
# 309:	learn: 0.0506563	total: 4m 50s	remaining: 2m 58s
# 310:	learn: 0.0506394	total: 4m 51s	remaining: 2m 57s
# 311:	learn: 0.0504386	total: 4m 52s	remaining: 2m 56s
# 312:	learn: 0.0503935	total: 4m 53s	remaining: 2m 55s
# 313:	learn: 0.0502951	total: 4m 54s	remaining: 2m 54s
# 314:	learn: 0.0502475	total: 4m 55s	remaining: 2m 53s
# 315:	learn: 0.0502091	total: 4m 56s	remaining: 2m 52s
# 316:	learn: 0.0501188	total: 4m 57s	remaining: 2m 51s
# 317:	learn: 0.0500779	total: 4m 58s	remaining: 2m 50s
# 318:	learn: 0.0500065	total: 4m 59s	remaining: 2m 50s
# 319:	learn: 0.0499441	total: 5m	remaining: 2m 49s
# 320:	learn: 0.0498107	total: 5m 1s	remaining: 2m 48s
# 321:	learn: 0.0497756	total: 5m 3s	remaining: 2m 47s
# 322:	learn: 0.0497396	total: 5m 4s	remaining: 2m 46s
# 323:	learn: 0.0496540	total: 5m 5s	remaining: 2m 45s
# 324:	learn: 0.0496042	total: 5m 6s	remaining: 2m 44s
# 325:	learn: 0.0495176	total: 5m 7s	remaining: 2m 44s
# 326:	learn: 0.0494832	total: 5m 8s	remaining: 2m 43s
# 327:	learn: 0.0492580	total: 5m 9s	remaining: 2m 42s
# 328:	learn: 0.0492128	total: 5m 10s	remaining: 2m 41s
# 329:	learn: 0.0491041	total: 5m 11s	remaining: 2m 40s
# 330:	learn: 0.0490551	total: 5m 12s	remaining: 2m 39s
# 331:	learn: 0.0490178	total: 5m 13s	remaining: 2m 38s
# 332:	learn: 0.0489397	total: 5m 14s	remaining: 2m 37s
# 333:	learn: 0.0488664	total: 5m 15s	remaining: 2m 36s
# 334:	learn: 0.0488391	total: 5m 16s	remaining: 2m 36s
# 335:	learn: 0.0486740	total: 5m 17s	remaining: 2m 35s
# 336:	learn: 0.0486534	total: 5m 19s	remaining: 2m 34s
# 337:	learn: 0.0485763	total: 5m 20s	remaining: 2m 33s
# 338:	learn: 0.0484957	total: 5m 21s	remaining: 2m 32s
# 339:	learn: 0.0483869	total: 5m 22s	remaining: 2m 31s
# 340:	learn: 0.0482864	total: 5m 23s	remaining: 2m 30s
# 341:	learn: 0.0479905	total: 5m 24s	remaining: 2m 29s
# 342:	learn: 0.0478698	total: 5m 25s	remaining: 2m 28s
# 343:	learn: 0.0477659	total: 5m 26s	remaining: 2m 27s
# 344:	learn: 0.0476616	total: 5m 27s	remaining: 2m 26s
# 345:	learn: 0.0474643	total: 5m 27s	remaining: 2m 25s
# 346:	learn: 0.0474534	total: 5m 28s	remaining: 2m 25s
# 347:	learn: 0.0473885	total: 5m 29s	remaining: 2m 24s
# 348:	learn: 0.0473454	total: 5m 31s	remaining: 2m 23s
# 349:	learn: 0.0472963	total: 5m 31s	remaining: 2m 22s
# 350:	learn: 0.0472411	total: 5m 33s	remaining: 2m 21s
# 351:	learn: 0.0472041	total: 5m 34s	remaining: 2m 20s
# 352:	learn: 0.0471148	total: 5m 35s	remaining: 2m 19s
# 353:	learn: 0.0470145	total: 5m 36s	remaining: 2m 18s
# 354:	learn: 0.0467125	total: 5m 37s	remaining: 2m 17s
# 355:	learn: 0.0466312	total: 5m 38s	remaining: 2m 16s
# 356:	learn: 0.0464916	total: 5m 39s	remaining: 2m 16s
# 357:	learn: 0.0463914	total: 5m 40s	remaining: 2m 15s
# 358:	learn: 0.0462799	total: 5m 41s	remaining: 2m 14s
# 359:	learn: 0.0462207	total: 5m 42s	remaining: 2m 13s
# 360:	learn: 0.0459716	total: 5m 43s	remaining: 2m 12s
# 361:	learn: 0.0458366	total: 5m 44s	remaining: 2m 11s
# 362:	learn: 0.0457140	total: 5m 45s	remaining: 2m 10s
# 363:	learn: 0.0455648	total: 5m 46s	remaining: 2m 9s
# 364:	learn: 0.0453135	total: 5m 47s	remaining: 2m 8s
# 365:	learn: 0.0452184	total: 5m 48s	remaining: 2m 7s
# 366:	learn: 0.0451987	total: 5m 49s	remaining: 2m 6s
# 367:	learn: 0.0450944	total: 5m 50s	remaining: 2m 5s
# 368:	learn: 0.0449552	total: 5m 51s	remaining: 2m 4s
# 369:	learn: 0.0448276	total: 5m 52s	remaining: 2m 3s
# 370:	learn: 0.0447361	total: 5m 53s	remaining: 2m 2s
# 371:	learn: 0.0447136	total: 5m 54s	remaining: 2m 1s
# 372:	learn: 0.0445055	total: 5m 55s	remaining: 2m
# 373:	learn: 0.0444428	total: 5m 56s	remaining: 2m
# 374:	learn: 0.0444143	total: 5m 57s	remaining: 1m 59s
# 375:	learn: 0.0442754	total: 5m 58s	remaining: 1m 58s
# 376:	learn: 0.0442088	total: 5m 59s	remaining: 1m 57s
# 377:	learn: 0.0441026	total: 6m	remaining: 1m 56s
# 378:	learn: 0.0440751	total: 6m 1s	remaining: 1m 55s
# 379:	learn: 0.0437936	total: 6m 2s	remaining: 1m 54s
# 380:	learn: 0.0436585	total: 6m 3s	remaining: 1m 53s
# 381:	learn: 0.0436201	total: 6m 4s	remaining: 1m 52s
# 382:	learn: 0.0435653	total: 6m 5s	remaining: 1m 51s
# 383:	learn: 0.0433793	total: 6m 6s	remaining: 1m 50s
# 384:	learn: 0.0432931	total: 6m 7s	remaining: 1m 49s
# 385:	learn: 0.0432536	total: 6m 9s	remaining: 1m 49s
# 386:	learn: 0.0430901	total: 6m 10s	remaining: 1m 48s
# 387:	learn: 0.0430571	total: 6m 11s	remaining: 1m 47s
# 388:	learn: 0.0430089	total: 6m 12s	remaining: 1m 46s
# 389:	learn: 0.0429329	total: 6m 13s	remaining: 1m 45s
# 390:	learn: 0.0428704	total: 6m 14s	remaining: 1m 44s
# 391:	learn: 0.0427848	total: 6m 15s	remaining: 1m 43s
# 392:	learn: 0.0425862	total: 6m 15s	remaining: 1m 42s
# 393:	learn: 0.0424071	total: 6m 16s	remaining: 1m 41s
# 394:	learn: 0.0423466	total: 6m 17s	remaining: 1m 40s
# 395:	learn: 0.0422033	total: 6m 18s	remaining: 1m 39s
# 396:	learn: 0.0420295	total: 6m 19s	remaining: 1m 38s
# 397:	learn: 0.0418594	total: 6m 20s	remaining: 1m 37s
# 398:	learn: 0.0417765	total: 6m 21s	remaining: 1m 36s
# 399:	learn: 0.0416851	total: 6m 22s	remaining: 1m 35s
# 400:	learn: 0.0415275	total: 6m 23s	remaining: 1m 34s
# 401:	learn: 0.0414877	total: 6m 24s	remaining: 1m 33s
# 402:	learn: 0.0414605	total: 6m 26s	remaining: 1m 32s
# 403:	learn: 0.0414165	total: 6m 27s	remaining: 1m 32s
# 404:	learn: 0.0413500	total: 6m 28s	remaining: 1m 31s
# 405:	learn: 0.0412863	total: 6m 29s	remaining: 1m 30s
# 406:	learn: 0.0412555	total: 6m 30s	remaining: 1m 29s
# 407:	learn: 0.0411656	total: 6m 31s	remaining: 1m 28s
# 408:	learn: 0.0411404	total: 6m 32s	remaining: 1m 27s
# 409:	learn: 0.0410127	total: 6m 33s	remaining: 1m 26s
# 410:	learn: 0.0409399	total: 6m 34s	remaining: 1m 25s
# 411:	learn: 0.0409278	total: 6m 35s	remaining: 1m 24s
# 412:	learn: 0.0408496	total: 6m 36s	remaining: 1m 23s
# 413:	learn: 0.0408233	total: 6m 37s	remaining: 1m 22s
# 414:	learn: 0.0407917	total: 6m 38s	remaining: 1m 21s
# 415:	learn: 0.0407048	total: 6m 39s	remaining: 1m 20s
# 416:	learn: 0.0405956	total: 6m 40s	remaining: 1m 19s
# 417:	learn: 0.0404917	total: 6m 41s	remaining: 1m 18s
# 418:	learn: 0.0404070	total: 6m 42s	remaining: 1m 17s
# 419:	learn: 0.0403952	total: 6m 43s	remaining: 1m 16s
# 420:	learn: 0.0402579	total: 6m 44s	remaining: 1m 15s
# 421:	learn: 0.0401829	total: 6m 45s	remaining: 1m 15s
# 422:	learn: 0.0400691	total: 6m 46s	remaining: 1m 14s
# 423:	learn: 0.0400282	total: 6m 48s	remaining: 1m 13s
# 424:	learn: 0.0400104	total: 6m 49s	remaining: 1m 12s
# 425:	learn: 0.0399513	total: 6m 50s	remaining: 1m 11s
# 426:	learn: 0.0398174	total: 6m 51s	remaining: 1m 10s
# 427:	learn: 0.0397754	total: 6m 52s	remaining: 1m 9s
# 428:	learn: 0.0397242	total: 6m 53s	remaining: 1m 8s
# 429:	learn: 0.0396783	total: 6m 54s	remaining: 1m 7s
# 430:	learn: 0.0395766	total: 6m 55s	remaining: 1m 6s
# 431:	learn: 0.0395239	total: 6m 56s	remaining: 1m 5s
# 432:	learn: 0.0394526	total: 6m 57s	remaining: 1m 4s
# 433:	learn: 0.0394132	total: 6m 58s	remaining: 1m 3s
# 434:	learn: 0.0392785	total: 6m 59s	remaining: 1m 2s
# 435:	learn: 0.0390426	total: 7m	remaining: 1m 1s
# 436:	learn: 0.0388245	total: 7m 1s	remaining: 1m
# 437:	learn: 0.0387177	total: 7m 2s	remaining: 59.8s
# 438:	learn: 0.0386631	total: 7m 3s	remaining: 58.9s
# 439:	learn: 0.0385004	total: 7m 4s	remaining: 57.9s
# 440:	learn: 0.0384348	total: 7m 5s	remaining: 57s
# 441:	learn: 0.0384294	total: 7m 6s	remaining: 56s
# 442:	learn: 0.0383734	total: 7m 7s	remaining: 55s
# 443:	learn: 0.0383506	total: 7m 8s	remaining: 54.1s
# 444:	learn: 0.0382816	total: 7m 9s	remaining: 53.1s
# 445:	learn: 0.0381686	total: 7m 10s	remaining: 52.2s
# 446:	learn: 0.0380661	total: 7m 11s	remaining: 51.2s
# 447:	learn: 0.0379828	total: 7m 13s	remaining: 50.3s
# 448:	learn: 0.0379583	total: 7m 14s	remaining: 49.3s
# 449:	learn: 0.0378590	total: 7m 15s	remaining: 48.4s
# 450:	learn: 0.0378238	total: 7m 16s	remaining: 47.4s
# 451:	learn: 0.0378106	total: 7m 17s	remaining: 46.4s
# 452:	learn: 0.0377172	total: 7m 18s	remaining: 45.5s
# 453:	learn: 0.0375970	total: 7m 19s	remaining: 44.5s
# 454:	learn: 0.0374455	total: 7m 20s	remaining: 43.5s
# 455:	learn: 0.0374177	total: 7m 21s	remaining: 42.6s
# 456:	learn: 0.0373137	total: 7m 22s	remaining: 41.6s
# 457:	learn: 0.0372257	total: 7m 23s	remaining: 40.7s
# 458:	learn: 0.0371118	total: 7m 24s	remaining: 39.7s
# 459:	learn: 0.0370096	total: 7m 25s	remaining: 38.7s
# 460:	learn: 0.0368959	total: 7m 26s	remaining: 37.7s
# 461:	learn: 0.0368598	total: 7m 27s	remaining: 36.8s
# 462:	learn: 0.0368441	total: 7m 28s	remaining: 35.8s
# 463:	learn: 0.0367814	total: 7m 29s	remaining: 34.9s
# 464:	learn: 0.0367032	total: 7m 30s	remaining: 33.9s
# 465:	learn: 0.0366907	total: 7m 31s	remaining: 33s
# 466:	learn: 0.0366434	total: 7m 33s	remaining: 32s
# 467:	learn: 0.0365387	total: 7m 34s	remaining: 31s
# 468:	learn: 0.0364209	total: 7m 35s	remaining: 30.1s
# 469:	learn: 0.0363835	total: 7m 35s	remaining: 29.1s
# 470:	learn: 0.0362827	total: 7m 36s	remaining: 28.1s
# 471:	learn: 0.0362322	total: 7m 37s	remaining: 27.2s
# 472:	learn: 0.0361488	total: 7m 38s	remaining: 26.2s
# 473:	learn: 0.0360835	total: 7m 39s	remaining: 25.2s
# 474:	learn: 0.0360049	total: 7m 40s	remaining: 24.2s
# 475:	learn: 0.0358988	total: 7m 41s	remaining: 23.3s
# 476:	learn: 0.0358187	total: 7m 42s	remaining: 22.3s
# 477:	learn: 0.0357324	total: 7m 43s	remaining: 21.3s
# 478:	learn: 0.0356837	total: 7m 44s	remaining: 20.4s
# 479:	learn: 0.0356324	total: 7m 45s	remaining: 19.4s
# 480:	learn: 0.0355902	total: 7m 46s	remaining: 18.4s
# 481:	learn: 0.0355476	total: 7m 47s	remaining: 17.5s
# 482:	learn: 0.0355387	total: 7m 48s	remaining: 16.5s
# 483:	learn: 0.0354609	total: 7m 49s	remaining: 15.5s
# 484:	learn: 0.0354543	total: 7m 50s	remaining: 14.6s
# 485:	learn: 0.0354363	total: 7m 51s	remaining: 13.6s
# 486:	learn: 0.0353178	total: 7m 53s	remaining: 12.6s
# 487:	learn: 0.0353116	total: 7m 54s	remaining: 11.7s
# 488:	learn: 0.0352306	total: 7m 54s	remaining: 10.7s
# 489:	learn: 0.0351347	total: 7m 55s	remaining: 9.71s
# 490:	learn: 0.0351025	total: 7m 56s	remaining: 8.74s
# 491:	learn: 0.0350699	total: 7m 57s	remaining: 7.77s
# 492:	learn: 0.0350104	total: 7m 58s	remaining: 6.8s
# 493:	learn: 0.0349942	total: 8m	remaining: 5.83s
# 494:	learn: 0.0349490	total: 8m 1s	remaining: 4.86s
# 495:	learn: 0.0347418	total: 8m 2s	remaining: 3.89s
# 496:	learn: 0.0347365	total: 8m 3s	remaining: 2.92s
# 497:	learn: 0.0347300	total: 8m 4s	remaining: 1.95s
# 498:	learn: 0.0346753	total: 8m 5s	remaining: 973ms
# 499:	learn: 0.0345048	total: 8m 6s	remaining: 0us
# CPU times: total: 51min 11s
# Wall time: 8min 9s

# %%
fi = pd.DataFrame(cb.feature_importances_, index=X_train.columns, columns=['importance'])
fi.sort_values(by='importance', ascending=False)
# Out:
#                             importance
# avg_transaction_category     16.185627
# n_sold_category              14.924851
# Word2Vec_distance_from_avg    7.217838
# n_transactions_per_week       5.817501
# avg_cheque                    5.555884
# avg_interval                  5.548832
# user_id                       5.409517
# avg_price                     4.580082
# avg_basket_department         4.390990
# price                         4.301500
# Word2Vec_length               3.537982
# item_id                       3.440857
# n_unique_stores               3.217803
# quantity_per_week             2.738711
# commodity_desc                1.725012
# department                    1.588669
# income_desc                   1.366923
# curr_size_of_product          1.177754
# age_desc                      1.151540
# sub_commodity_desc            1.089287
# manufacturer                  0.995396
# hh_comp_desc                  0.922167
# marital_status_code           0.701220
# household_size_desc           0.640522
# kid_category_desc             0.558811
# Last5sales                    0.544924
# homeowner_desc                0.482193
# brand                         0.096451
# item_score                    0.088435
# Missing quantity per week     0.002718
# Missing price                 0.000000

# %% [markdown]
# ### Оценим качество построенной модели с помощью метрики precision@5 на валидационном датасете.

# %%
df_ranker_predict = df_ranker_train.copy()
df_ranker_predict['proba_item_purchase'] = train_preds[:,1]

# %%
N_PREDICT = 100
TOPK_PRECISION = 5

result_eval_ranker = data_val_ranker.groupby(USER_COL)[ITEM_COL].unique().reset_index()
result_eval_ranker.columns=[USER_COL, ACTUAL_COL]
result_eval_ranker['own_rec'] = make_recommendations(result_eval_ranker, 
                                                     recommender.get_own_recommendations, N_PREDICT=N_PREDICT)

sorted(calc_precision(result_eval_ranker, TOPK_PRECISION), key=lambda x: x[1], reverse=True)
# Out:
# [('own_rec', 0.10107843137254902)]

# %%
result_eval_ranker['reranked_own_rec'] = result_eval_ranker[USER_COL].\
                                            apply(lambda user_id: rerank(user_id, df_ranker_predict))
print(*sorted(calc_precision(result_eval_ranker, TOPK_PRECISION), key=lambda x: x[1], reverse=True), sep='\n')
# Out:
# ('reranked_own_rec', 0.18250666666666668)
# ('own_rec', 0.10107843137254902)

# %% [markdown]
# Как видим с помощью модели второго уровня удалось значительно поднять метрики для построенных рекомендаций.
#
# ### 7. Рекомендации для тестового датасета
#
# Теперь построим предсказания для итогового датасета.

# %%
data_test = pd.read_csv('retail_test1.csv')
data_test.head()
# Out:
#    user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 0     1340  41652823310  664   912987         1         8.49       446
# 1      588  41652838477  664  1024426         1         6.29       388
# 2     2070  41652857291  664   995242         5         9.10       311
# 3     1602  41665647035  664   827939         1         7.99       334
# 4     1602  41665647035  664   927712         1         0.59       334
#
#    retail_disc  trans_time  week_no  coupon_disc  coupon_match_disc
# 0          0.0          52       96          0.0                0.0
# 1          0.0           8       96          0.0                0.0
# 2         -0.6          46       96          0.0                0.0
# 3          0.0        1741       96          0.0                0.0
# 4         -0.4        1741       96          0.0                0.0

# %%
df_test_candidates = pd.DataFrame(data_test[USER_COL].unique())
df_test_candidates.columns = [USER_COL]

df_test_candidates['recommendations'] = df_test_candidates[USER_COL].\
                                        apply(lambda user_id: rerank(user_id, df_ranker_predict))

# %%
# сохраняем полученные рекомендации в файл.

df_test_candidates.to_csv('recommendations.csv', index=False)
df_test_candidates.head()
# Out:
#    user_id                              recommendations
# 0     1340  [1037840, 852856, 1075368, 986912, 1029743]
# 1      588    [899624, 933835, 907631, 1106523, 866211]
# 2     2070     [899624, 916122, 865456, 913210, 838186]
# 3     1602   [1070820, 832678, 872137, 901062, 6034857]
# 4      447  [899624, 1004906, 1106523, 909714, 1029743]
